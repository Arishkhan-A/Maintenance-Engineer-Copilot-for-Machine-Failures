# %% [markdown]
# # Notebook 03: Predictive Model Experiments & Evaluation
# Comparing Logistic Regression, Random Forest, XGBoost, and Isolation Forest.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report, roc_auc_score
from src.models.train_failure import train_failure_models
from src.models.train_rul import train_rul_model
from src.anomaly.detector import train_anomaly_model

# Run training modules
fail_metrics = train_failure_models('../data/raw/machine_predictive_maintenance.csv', models_dir='../models')
print('Failure Model Result:', fail_metrics)

rul_metrics = train_rul_model('../data/raw/machine_predictive_maintenance.csv', models_dir='../models')
print('RUL Model Result:', rul_metrics)

anom_metrics = train_anomaly_model('../data/raw/machine_predictive_maintenance.csv', models_dir='../models')
print('Anomaly Detector Result:', anom_metrics)

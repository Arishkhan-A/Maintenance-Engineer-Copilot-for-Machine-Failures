# %% [markdown]
# # Notebook 01: Data Understanding & Initial Inspection
# Maintenance Engineer Copilot Phase 1 - Understanding Dataset Schema, Missing Values, and Lineage.

# %%
import pandas as pd
import numpy as np

# Load raw dataset
df = pd.read_csv('../data/raw/machine_predictive_maintenance.csv')
print('Dataset Shape:', df.shape)
print('\nColumns and Types:\n', df.dtypes)
df.head()

# %%
# Missing values and Duplicates Check
print('Missing values per column:\n', df.isna().sum())
print('\nDuplicate rows:', df.duplicated().sum())
print('\nMachine IDs in dataset:', df['machine_id'].nunique())
print('Machine types:', df['machine_type'].value_counts())

# %%
# Statistical summary
df.describe()
